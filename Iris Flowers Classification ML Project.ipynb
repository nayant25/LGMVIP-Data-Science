# %% [markdown]
# # ASHITA K
# # BEGINNER LEVEL TASK 1:
# # 1) Iris Flowers Classification ML Project

# %% [markdown]
# # Import Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Loading the dataset

# %%
iris_dataset=pd.read_csv("iris.csv")
print(iris_dataset)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris_dataset.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_dataset.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris_dataset.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris_dataset.shape
# Out:
# (150, 6)

# %%
iris_dataset.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris_dataset['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# # Preprocessing the dataset

# %%
iris_dataset.isna().any()
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
iris_dataset.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris_dataset=iris_dataset.drop(columns=['Id'])
iris_dataset.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Exploratory data analysis

# %%
sns.set(rc={'figure.figsize':(10,5)})
sns.lineplot(x="SepalLengthCm", y="SepalWidthCm", data=iris_dataset)
plt.show()

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="PetalWidthCm", y="PetalLengthCm", data=iris_dataset)
plt.show()

# %%
sns.set(rc={'figure.figsize':(10,5)})
sns.barplot(x="SepalLengthCm", y="SepalWidthCm", data=iris_dataset)
plt.show()

# %%
sns.set(rc={'figure.figsize':(10,5)})
sns.barplot(x="PetalLengthCm", y="PetalWidthCm", data=iris_dataset)
plt.show()

# %%
sns.pairplot(iris_dataset)

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.boxplot(x="SepalLengthCm", y="SepalWidthCm", data=iris_dataset)
plt.show()

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.boxplot(x="PetalLengthCm", y="PetalWidthCm", data=iris_dataset)
plt.show()

# %%
sns.boxplot(x='SepalWidthCm', hue='Species', data=iris_dataset)
# Out:
# <AxesSubplot:xlabel='SepalWidthCm'>

# %%
sns.boxplot(x='SepalLengthCm', hue='Species', data=iris_dataset)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm'>

# %%
sns.boxplot(x='PetalWidthCm', hue='Species', data=iris_dataset)
# Out:
# <AxesSubplot:xlabel='PetalWidthCm'>

# %%
sns.boxplot(x='PetalWidthCm', hue='Species', data=iris_dataset)
# Out:
# <AxesSubplot:xlabel='PetalWidthCm'>

# %%
iris_dataset['SepalWidthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
iris_dataset['SepalLengthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
iris_dataset['PetalWidthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
iris_dataset['PetalLengthCm'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Correlation matrix

# %%
iris_dataset.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
corr = iris_dataset.corr()
fig, ax = plt.subplots(figsize=(10,5))
sns.heatmap(corr, square=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Model training

# %%
X=iris_dataset.drop(columns=['Species'])
Y=iris_dataset['Species']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
print("Accuracy is : ", model.score(x_test,y_test)*100)
# Out:
# Accuracy is :  100.0

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy is : ", model.score(x_test,y_test)*100)
# Out:
# Accuracy is :  100.0
